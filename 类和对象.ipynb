# %%
class human:
    def sleep(self):
        print("睡着了")
    human_name="小伟"
human1=human()
human2=human()
human1.sleep()
print(human1.human_name)
# Out:
# 睡着了
# 小伟

# %%
print(id(human1))
print(id(human2))
# Out:
# 2556272736592
# 2556269415552
